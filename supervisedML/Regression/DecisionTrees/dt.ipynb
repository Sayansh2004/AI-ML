# %% [markdown]
# we decided the feature based on which we want to split the tree.
#
# We split the data into two parts and repeat recursively.
#
# Since it is a regression problem so it takes the average of all the values at the leaf node. Here our focus on reducing the variance as much as possible . (Mean sqaured error)  -- > variance reduction.
